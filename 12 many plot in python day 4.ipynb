# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

nuqta=sns.load_dataset("dots")
nuqta.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
#these are time series plot

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")

#defining a color pelette
p= sns.color_palette("rocket_r")

#plot lineplot

sns.relplot(
    data=nuqta,
    x="time",y="firing_rate",
    hue="coherence",size="choice",col="align",
    kind="line",size_order=["T1","T2"],palette=p,
    height=5,aspect=.75,facet_kws=dict(sharex=False),
)

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")

#defining a color pelette
p= sns.color_palette("rocket_r")

#plot lineplot

sns.relplot(
    data=kashti,
    x="survived	",y="who",
    hue="coherence",size="choice",col="align",
    kind="line",size_order=["T1","T2"],palette=p,
    height=5,aspect=.75,facet_kws=dict(sharex=False),
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-7fea06419960> in <module>
#      16     hue="coherence",size="choice",col="align",
#      17     kind="line",size_order=["T1","T2"],palette=p,
# ---> 18     height=5,aspect=.75,facet_kws=dict(sharex=False),
#      19 )
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1663         sizes=sizes, size_order=size_order, size_norm=size_norm,
#    1664         markers=markers, dashes=dashes, style_order=style_order,
# -> 1665         legend=legend,
#    1666     )
#    1667
#
# ...

# %%
import seaborn as sns
sns.set_theme(style="ticks",palette="pastel")# theme nhi mill rha

#load the example tips dataset
tips=sns.load_dataset("tips")

#draw a nested boxplot to show bills by day and time
sns.boxplot(x="day",y="total_bill",
           hue="smoker",palette=["m","g"],
           data=tips)
sns.dispine(offset=10,trim=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-672cd6647cd2> in <module>
#       1 import seaborn as sns
# ----> 2 sns.set_theme(style="ticks",palette="pastel")
#       3
#       4 #load the example tips dataset
#       5 tips=sns.load_dataset("tips")
#
# AttributeError: module 'seaborn' has no attribute 'set_theme'

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sns.set_style("ticks")

#load the example tips dataset
tips=sns.load_dataset("tips")

#draw a nested boxplot to show bills by day and time
sns.boxplot(x="day",y="total_bill",
           hue="smoker",palette=["m","g"],
           data=tips)
sns.despine(offset=10,trim=True)

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sns.set_style("ticks")
sns.set_palette("pastel")

#load the example tips dataset
tips=sns.load_dataset("tips")

#draw a nested boxplot to show bills by day and time
sns.boxplot(x="day",y="total_bill",
           hue="smoker",palette=["m","g"],
           data=tips)
sns.despine(offset=10,trim=True)

# %%
import seaborn install theme
# Out:
#   File "<ipython-input-7-fef127bd9367>", line 1
#     import seaborn install theme
#                          ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
sns.set_style("whitegrid")

#load the example tips dataset
tips=sns.load_dataset("tips")

#draw a nested violinplot  and split the violion for easieer comparision

sns.violinplot(data=tips,x="day",y="total_bill",hue="smoker",
              split=True,inner="quart",linewidth=1,
              palette={"Yes":"b","No":"0.85"})
sns.despine(left=True)

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style("whitegrid")
              
#load the example diamonds dataset
diamonds=sns.load_dataset("diamonds")
              
# draw a scatter plot while assigning point color and sizes to different 
# variable in the dataset

f,ax = plt.subplots(figsize=(6.5,6.5))
sns.despine(f,left=True ,bottom=True)
clarity_ranking=["I1","SI1","SI2","VS2","VS1","VVS2","VVS1","IF"]
sns.scatterplot(x="carat",y="price",
                hue="clarity",size="depth",
                palette="ch:r=-.2,d=3_r",
                hue_order=clarity_ranking,
                sizes=(1,8),linewidth =0,
                data=diamonds,ax=ax)

# %%
import seaborn as sns
sns.set_style("ticks")

df=sns.load_dataset("penguins")
sns.pairplot(df, hue= "species")

# %%
#need to expert in staticts for read the plot
